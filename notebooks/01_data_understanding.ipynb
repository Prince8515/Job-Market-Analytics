# %%
import pandas as pd

# %%
df=pd.read_csv("/content/raw_data/gsearch_jobs.csv")
df.head()
# Out:
#    Unnamed: 0  index                                             title  \
# 0           0      0                                      Data Analyst
# 1           1      1                                      Data Analyst
# 2           2      2                         Aeronautical Data Analyst
# 3           3      3  Data Analyst - Consumer Goods - Contract to Hire
# 4           4      4               Data Analyst | Workforce Management
#
#                  company_name            location           via  \
# 0                        Meta           Anywhere   via LinkedIn
# 1                         ATC    United States     via LinkedIn
# 2  Garmin International, Inc.       Olathe, KS       via Indeed
# 3                      Upwork           Anywhere     via Upwork
# 4                Krispy Kreme    United States     via LinkedIn
#
#                                          description  \
# 0  In the intersection of compliance and analytic...
# ...

# %%
df.tail()
# Out:
#        Unnamed: 0  index                                              title  \
# 61948       61948    955                     Marketing Data & BI Analyst II
# 61949       61949    956                                  Lead-Data Analyst
# 61950       61950    957                                  Lead-Data Analyst
# 61951       61951    958                                  Lead-Data Analyst
# 61952       61952    959  Institutional Credit Management - Lending Data...
#
#        company_name        location                    via  \
# 61948  EDWARD JONES   Houstonia, MO  via My ArkLaMiss Jobs
# 61949  EDWARD JONES  Marshfield, MO  via My ArkLaMiss Jobs
# 61950  EDWARD JONES  High Point, MO  via My ArkLaMiss Jobs
# 61951  EDWARD JONES     Calhoun, MO  via My ArkLaMiss Jobs
# 61952          Citi   United States  via My ArkLaMiss Jobs
#
#                                              description  \
# 61948  At Edward Jones, we help clients achieve their...
# ...

# %%
df.sample(5)
# Out:
#        Unnamed: 0  index                                              title  \
# 32059       32059     16                              Business Intelligence
# 31535       31535   1887                                Senior Data Analyst
# 20347       20347    187                            Complaints Data Analyst
# 29562       29562   2535  United States (Remote) Senior Data Analyst, Ma...
# 24074       24074   1337                                  Data Scientist II
#
#                  company_name            location              via  \
# 32059  Seacoast National Bank      Wichita, KS           via BeBee
# 31535   Continental Resources     Del City, OK           via BeBee
# 20347    JPMorgan Chase & Co.    United States     via Trabajo.org
# 29562            vmysmartpros            Anywhere      Mysmartpros
# 24074               ClassPass           Anywhere      via LinkedIn
#
#                                              description  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61953 entries, 0 to 61952
# Data columns (total 27 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           61953 non-null  int64
#  1   index                61953 non-null  int64
#  2   title                61953 non-null  object
#  3   company_name         61953 non-null  object
#  4   location             61916 non-null  object
#  5   via                  61944 non-null  object
#  6   description          61953 non-null  object
#  7   extensions           61953 non-null  object
#  8   job_id               61953 non-null  object
#  9   thumbnail            38194 non-null  object
#  10  posted_at            61763 non-null  object
#  11  schedule_type        61707 non-null  object
#  12  work_from_home       27980 non-null  object
#  13  salary               10088 non-null  object
#  14  search_term          61953 non-null  object
# ...

# %%
print("No.of rows :",df.shape[0])
print("No.of columns :",df.shape[1])
print("No.of numeric columns :",df.select_dtypes(include='number').shape[1])
print("No.of object columns :",df.select_dtypes(include='object').shape[1])
# Out:
# No.of rows : 61953
# No.of columns : 27
# No.of numeric columns : 9
# No.of object columns : 18

# %%
df.describe()
# Out:
#          Unnamed: 0         index  commute_time     salary_avg     salary_min  \
# count  61953.000000  61953.000000           0.0   10088.000000    9512.000000
# mean   30976.000000   1139.077333           NaN   42100.231239   34846.281874
# std    17884.434951    690.256113           NaN   55893.993519   45843.034891
# min        0.000000      0.000000           NaN       7.250000       8.000000
# 25%    15488.000000    553.000000           NaN      31.500000      19.520000
# 50%    30976.000000   1111.000000           NaN      60.000000      50.000000
# 75%    46464.000000   1685.000000           NaN   92500.000000   77000.000000
# max    61952.000000   3228.000000           NaN  550000.000000  450000.000000
#
#           salary_max  salary_hourly  salary_yearly  salary_standardized
# count    9512.000000    5900.000000    4069.000000         10088.000000
# mean    50487.856787      40.539588  104115.406718         92289.425683
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                 0
# index                      0
# title                      0
# company_name               0
# location                  37
# via                        9
# description                0
# extensions                 0
# job_id                     0
# thumbnail              23759
# posted_at                190
# schedule_type            246
# work_from_home         33973
# salary                 51865
# search_term                0
# date_time                  0
# search_location            0
# commute_time           61953
# salary_pay             51865
# salary_rate            51865
# salary_avg             51865
# salary_min             52441
# salary_max             52441
# salary_hourly          56053
# salary_yearly          57884
# salary_standardized    51865
# description_tokens         0
# dtype: int64

# %%
print("Most null columns :",df.isnull().sum().idxmax())
# Out:
# Most null columns : commute_time

# %%
print("Minimum null columns :",df.isnull().sum().idxmin())
# Out:
# Most null columns : Unnamed: 0

# %%
snc=(df.isnull().sum() > 0).sum()
print("Sum of null columns :",snc)
# Out:
# Sum of null columns : 16

# %%
dr=df.duplicated().sum()
print("Sum of duplicate rows :",dr)
# Out:
# Sum of duplicate rows : 0

# %%
print("Common job role :",df['title'].value_counts().idxmax()," and Job-avialabe :",df['title'].value_counts().max())
# Out:
# Common job role : Data Analyst  and Job-avialabe : 6444

# %%
print("Unique-roles :",df['title'].value_counts().unique().sum())
# Out:
# Unique-roles : 18201

# %%
print("Common job location:",df['location'].value_counts().idxmax())
# Out:
# Common job location:  Anywhere

# %%
print("Unique-location :",df['location'].value_counts().unique().sum())
# Out:
# Unique-location : 56576

# %%
print("Common job sources:",df['via'].value_counts().idxmax())
# Out:
# Common job sources: via LinkedIn

# %%
print("Unique-job_sources :",df['via'].value_counts().unique().sum())
# Out:
# Unique-job_sources : 57632

# %%
print("Common job schedule_type:",df['schedule_type'].value_counts().idxmax())
# Out:
# Common job schedule_type: Full-time

# %%
print("Unique-job_schedule_type:",df['schedule_type'].value_counts().unique().sum())
# Out:
# Unique-job_schedule_type: 61672

# %%
 print("No.job avilable for work_from_home :",df['work_from_home'].value_counts().max())
# Out:
# No.job avilable for work_from_home : 27980

# %%
df['work_from_home'].count()
# Out:
# np.int64(27980)

# %%
salary=df['salary_avg']

# %%
salary.describe()
# Out:
# count     10088.000000
# mean      42100.231239
# std       55893.993519
# min           7.250000
# 25%          31.500000
# 50%          60.000000
# 75%       92500.000000
# max      550000.000000
# Name: salary_avg, dtype: float64

# %%
salary.median()
# Out:
# 60.0

# %%
df.groupby('salary')['title'].value_counts()
# Out:
# salary             title
# 1.8K–2.4K a month  Finance Data Analyst                                                                                  1
# 10 an hour         Data Analyst                                                                                          2
#                    Data Analyst - Contract to Hire                                                                       1
#                    Expert Questionnaire Writer data collector, data analyst and lead generator, in arabic and english    1
#                    Financial & data analyst guru - Contract to hire                                                      1
#                                                                                                                         ..
# 9–18 an hour       Data analyst                                                                                          1
# ...

# %% [markdown]
# TOP 5 OBSERVATIONS
#
# 1. Data Analyst is the most frequently occurring job title in the dataset.
# 2. **Missing Data:** A significant number of columns have missing values; notably, the 'commute_time' column is entirely null, and salary-related fields also have many missing entries.
# 3. **No Duplicate Records:** The dataset does not contain any duplicate rows, ensuring data uniqueness.
# 4. **Flexible Work Locations:** 'Anywhere' is the most common job location, suggesting a high availability of remote or location-agnostic roles.
# 5. **Predominant Job Characteristics:** 'Full-time' is the most frequent job schedule type, and 'via LinkedIn' is the most common source for job postings.
